# %% [markdown]
# # Google Playstore Case Study

# %% [markdown]
# In this module you’ll be learning data visualisation with the help of a case study. This will enable you to understand how visualisation aids you in solving business problems.

# %% [markdown]
# **Problem Statement**
#
# The team at Google Play Store wants to develop a feature that would enable them to boost visibility for the most promising apps. Now, this analysis would require a preliminary understanding of the features that define a well-performing app. You can ask questions like:
# - Does a higher size or price necessarily mean that an app would perform better than the other apps?
# - Or does a higher number of installs give a clear picture of which app would have a better rating than others?

# %% [markdown]
# ### Session 1 - Introduction to Data Visualisation

# %%
#import the libraries
import matplotlib
import pandas as pd

# %%
#read the dataset and check the first five rows
df = pd.read_csv("C:/Users/vishal.patial/Desktop/MachineLearningWithPython/EDA/INvideos.csv")
df.head()
# Out:
#       video_id trending_date  \
# 0  kzwfHumJyYc      17.14.11
# 1  10L1hZ9qa58      17.14.11
# 2  N1vE8iiEg64      17.14.11
# 3  kJzGH0PVQHQ      17.14.11
# 4  il_pSa5l98w      17.14.11
#
#                                                title    channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...  Lokdhun Punjabi
# 1  Stylish Star Allu Arjun @ ChaySam Wedding Rece...             TFPC
# 2                     Eruma Saani | Tamil vs English      Eruma Saani
# 3  why Samantha became EMOTIONAL @ Samantha naga ...       Filmylooks
# 4  MCA (Middle Class Abbayi) TEASER - Nani,Sai Pa...         Dil Raju
#
#    category_id              publish_time  \
# 0            1  2017-11-12T12:20:39.000Z
# 1           24  2017-11-12T15:48:08.000Z
# 2           23  2017-11-12T07:08:48.000Z
# 3           24  2017-11-13T01:14:16.000Z
# 4           24  2017-11-10T04:29:50.000Z
#
#                                                 tags    views  likes  \
# 0  sharry mann|"sharry mann new song"|"sharry man...  1096327  33966
# 1  Stylish Star Allu Arjun @ ChaySam Wedding Rece...   473988   2011
# 2  Eruma Saani|"Tamil Comedy Videos"|"Films"|"Mov...  1242680  70353
# 3  Filmylooks|"latest news"|"telugu movies"|"telu...   464015    492
# 4  Nenu Local|"Nenu Local Telugu Movie"|"Nani"|"S...  6106669  98612
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0       798            882  https://i.ytimg.com/vi/kzwfHumJyYc/default.jpg
# 1       243            149  https://i.ytimg.com/vi/10L1hZ9qa58/default.jpg
# 2      1624           2684  https://i.ytimg.com/vi/N1vE8iiEg64/default.jpg
# 3       293             66  https://i.ytimg.com/vi/kJzGH0PVQHQ/default.jpg
# 4      4185           4763  https://i.ytimg.com/vi/il_pSa5l98w/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description
# 0  Presenting Sharry Mann latest Punjabi Song  Cu...
# 1  Watch Stylish Star Allu Arjun @ ChaySam Weddin...
# 2  This video showcases the difference between pe...
# 3  why Samantha became EMOTIONAL @ Samantha naga ...
# 4  Watch MCA- Middle Class Abbayi First Look Teas...

# %%
#Check the shape of the dataframe
df.size
df.shape
# Out:
# (37351, 16)

# %% [markdown]
# ### Data Handling and Cleaning

# %% [markdown]
# The first few steps involve making sure that there are no __missing values__ or __incorrect data types__ before we proceed to the analysis stage. These aforementioned problems are handled as follows:
#
#  - For Missing Values: Some common techniques to treat this issue are
#     - Dropping the rows containing the missing values
#     - Imputing the missing values
#     - Keep the missing values if they don't affect the analysis
#
#
#  - Incorrect Data Types:
#     - Clean certain values
#     - Clean and convert an entire column

# %%
#Check the datatypes of all the columns of the dataframe
df.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %% [markdown]
# #### Missing Value Treatment

# %%
#Check the number of null values in the columns.isnull().values.any()
df.isnull().values.any()
# Out:
# True

# %% [markdown]
# Handling missing values for rating
#  - Ratings is the target variable
#  - drop the records

# %%
#Drop the rows having null values in the Rating field
#df=inp0.dropna()
df = df[df['ratings_disabled'].notnull()]
df.size
df.shape
# Out:
# (37351, 16)

# %%
# Check the number of nulls in the Rating field again to cross-verify
non_null.isnull().shape
# Out:
# (36790, 16)

# %%
#Question
#Check the number of nulls in the dataframe again and find the total number of null values

df1=df.isnull()
df1.size
df1.shape
# Out:
# (37351, 16)

# %%
#Inspect the nulls in the Android Version column
df = df[df['channel_title'].notnull()]
df.size
df.shape
df
# Out:
#           video_id trending_date  \
# 0      kzwfHumJyYc      17.14.11
# 1      10L1hZ9qa58      17.14.11
# 2      N1vE8iiEg64      17.14.11
# 3      kJzGH0PVQHQ      17.14.11
# 4      il_pSa5l98w      17.14.11
# 5      7MxiQ4v0EnE      17.14.11
# 6      c64I9HNpiOY      17.14.11
# 7      KObFEYCaRx8      17.14.11
# 8      g8QsfJhFpjY      17.14.11
# 9      4du1KXBl4YU      17.14.11
# 10     zOOmEDwPJX0      17.14.11
# 11     Prb_osSVE0M      17.14.11
# 12     KHxdrECEsD0      17.14.11
# 13     so0ccfs-psI      17.14.11
# 14     7gShaSuK_PY      17.14.11
# 15     ep3SLMuRbvg      17.14.11
# 16     ePO5M5DE01I      17.14.11
# 17     CLl1RbxDRAs      17.14.11
# 18     1ZAPwfrtAFY      17.14.11
# 19     ZIHhuwvT7R0      17.14.11
# 20     Mqfh8_Uk1eM      17.14.11
# 21     1kuJkA9usqg      17.14.11
# 22     0SMKG3SRGzQ      17.14.11
# 23     znOC3IU0dF8      17.14.11
# 24     z3V9LUA6VQM      17.14.11
# 25     bx-QX2ZPH60      17.14.11
# 26     tFM-GNSeXzw      17.14.11
# 27     MF9ovM9y0PE      17.14.11
# 28     EJVvdjDGnak      17.14.11
# 29     Ukjn7A9L7vY      17.14.11
# ...            ...           ...
# 37321  IqGgdhPL_Lk      18.14.06
# 37322  mfC-E6oku9s      18.14.06
# 37323       #NAME?      18.14.06
# 37324  7gpdzfuVnzk      18.14.06
# 37325  Y3ouEQqzShk      18.14.06
# 37326  6H2bUCOZFPE      18.14.06
# 37327  kcjQ1xOcqjs      18.14.06
# 37328  brjifeZ5pyE      18.14.06
# 37329  K10YIAokjvE      18.14.06
# 37330  s5H7g9x4O-0      18.14.06
# 37331  wTs64bJRyLw      18.14.06
# 37332  AuSew0AGngE      18.14.06
# 37333  d8XlK90bz1M      18.14.06
# 37334  VhO2zRMhUcU      18.14.06
# 37335  pnD-jQSlpyA      18.14.06
# 37336  c5ZB0p0zBg0      18.14.06
# 37337  2B-r91bmAqc      18.14.06
# 37340  the viral fever|"tvf"|"humour"|"qtiyapa"|"come...    469379   21543
# 37341  zee24taas|"marathi video"|"marathi news"|"Brea...    339265     434
# 37342  hasley|"india"|"harsh"|"beniwal"|"rishhsome"|"...    447755   23896
# 37343  nagaland|"northeast"|"facebook"|"whatsapp"|"so...     56313    6687
# 37344  priyamanaval episode 1040|"Priyamanaval 13.06....    535254    3105
# 37345                                             [none]    274861   16448
# 37346  twinkle vaishnav comedy|"twinkle vaishnav"|"tw...    214378    3291
# 37347  flowers serials|"actress"|"malayalam serials"|...    406828    1726
# 37348  mazhavil manorama|"bhramanam full episode"|"gt...    386319    1216
# 37349  tarang|"tarang tv"|"tarang tv online"|"tarang ...    130263     698
# 37350  Ee Nagaraniki Emaindi|"Ee Nagaraniki Emaindi T...   1278249   22466
#
#        dislikes  comment_count  \
# 0           798            882
# 1           243            149
# 2          1624           2684
# 3           293             66
# 4          4185           4763
# 5          7134           8063
# 6          8812          10847
# 7            53             23
# 8          1545           2404
# 9          2183           2869
# 10          710           1743
# 11           53              0
# 12          250            174
# 13          180            594
# 14           59             18
# 15          417           2870
# 16        61195         101117
# 17          448           1105
# 18         6146          12703
# 19         1361            913
# 20          938            956
# 21         1214            711
# 22           52             23
# 23           94             15
# 24          197             66
# 25          368           1274
# 26           91             13
# 27           68            364
# 28          123             35
# 29          249            131
# ...         ...            ...
# 37321       247            579
# 37322      2410           2297
# 37323      5508          12726
# 37324       454            420
# 37325       489            469
# 37326       472            963
# 37327       612           2716
# 37328       126            108
# 37329       393           2107
# 37330      5557           2789
# 37331       190            106
# 37332       864           6230
# 37333       435            165
# 37334       862            155
# 37335       439           1713
# 37336       329            267
# 37337        95             52
# 37338       291            285
# 37339       101            609
# 37340      2579           1250
# 37341       185             73
# 37342      1304           1340
# 37343        57            556
# 37344      1403            898
# 37345       183            834
# 37346       404            196
# 37347       478           1428
# 37348       453            697
# 37349       115             65
# 37350      1609           1205
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/kzwfHumJyYc/default.jpg              False
# 1      https://i.ytimg.com/vi/10L1hZ9qa58/default.jpg              False
# 2      https://i.ytimg.com/vi/N1vE8iiEg64/default.jpg              False
# 3      https://i.ytimg.com/vi/kJzGH0PVQHQ/default.jpg              False
# 4      https://i.ytimg.com/vi/il_pSa5l98w/default.jpg              False
# 5      https://i.ytimg.com/vi/7MxiQ4v0EnE/default.jpg              False
# 6      https://i.ytimg.com/vi/c64I9HNpiOY/default.jpg              False
# 7      https://i.ytimg.com/vi/KObFEYCaRx8/default.jpg              False
# 8      https://i.ytimg.com/vi/g8QsfJhFpjY/default.jpg              False
# 9      https://i.ytimg.com/vi/4du1KXBl4YU/default.jpg              False
# 10     https://i.ytimg.com/vi/zOOmEDwPJX0/default.jpg              False
# 11     https://i.ytimg.com/vi/Prb_osSVE0M/default.jpg               True
# 12     https://i.ytimg.com/vi/KHxdrECEsD0/default.jpg              False
# 13     https://i.ytimg.com/vi/so0ccfs-psI/default.jpg              False
# 14     https://i.ytimg.com/vi/7gShaSuK_PY/default.jpg              False
# 15     https://i.ytimg.com/vi/ep3SLMuRbvg/default.jpg              False
# 16     https://i.ytimg.com/vi/ePO5M5DE01I/default.jpg              False
# 17     https://i.ytimg.com/vi/CLl1RbxDRAs/default.jpg              False
# 18     https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg              False
#
default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 0                 False                   False
# 1                 False                   False
# 2                 False                   False
# 3                 False                   False
# 4                 False                   False
# 5                 False                   False
# 6                 False                   False
# 7                 False                   False
# 8                 False                   False
# 9                 False                   False
# 10                False                   False
# 11                False                   False
# 12                False                   False
# 13                False                   False
# 14                False                   False
# 15                False                   False
# 16                False                   False
# 17                False                   False
# 18                False                   False
# 19                False                   False
# 20                False                   False
# 21                False                   False
# 22                False                   False
# 23                False                   False
# 24                False                   False
# 25                False                   False
# 26                False                   False
# 27                False                   False
# 28                False                   False
# 29                False                   False
# ...                 ...                     ...
# 37321             False                   False
# 37322             False                   False
# 37323             False                   False
# 37324             False                   False
# 37325             False                   False
# 37326             False                   False
# 37327             False                   False
# 37328             False                   False
# 37329             False                   False
# 37330             False                   False
# 37331             False                   False
# 37332             False                   False
# 37333             False                   False
# 37334             False                   False
# 37335             False                   False
# 37336             False                   False
# 37337             False                   False
# 37338             False                   False
# 37339             False                   False
# 37340             False                   False
# 37341             False                   False
# 37342             False                   False
# 37343             False                   False
# 37344             False                   False
# 37345             False                   False
# 37346             False                   False
# 37347             False                   False
# 37348             False                   False
# 37349             False                   False
# 37350             False                   False
#
#                                              description
# 0      Presenting Sharry Mann latest Punjabi Song  Cu...
# 1      Watch Stylish Star Allu Arjun @ ChaySam Weddin...
# 2      This video showcases the difference between pe...
# 3      why Samantha became EMOTIONAL @ Samantha naga ...
# 4      Watch MCA- Middle Class Abbayi First Look Teas...
# 5      Song - Daang\nSinger - Mankirt Aulakh\nFaceboo...
# 6      Presenting the song 'Ek Dil Ek Jaan' from Padm...
# 7      Chiranjeevi in Naga Chaitanya - Samantha Recep...
# 8      Jump Cuts is a Tamil entertaining group by Har...
# 9      Mehjabi Siddiqui reveals Hina Khan Dirty Polit...
# 10     A WHITE HILL MUSIC Presentation\nProduced by :...
# 11     Renu Desai gives a low rating for Pawan Kalyan...
# 12     Peehu Srivastav grabs the attention of the jud...
# 13     VS Records & Vikas Sethi Presents “ROWI NA” (D...
# 14     ஜெயலலிதாவின் உயில் சிக்கியது \nஅப்பல்லோ சி.டி....
# 15     This video shows different types of students p...
# 16     Stay updated! 🔔 Subscribe Now: https://goo.gl/...
# 17     Subscribe karo aur Bell Icon pe click karo \nI...
# 18     One year after the presidential election, John...
# 19     Asli Fighter (Dubbed Version of the Telugu Act...
# 20     A comedy show, in which comedians like Sudigaa...
# 21     Deivamagal Episode 1387\nSubscribe: https://go...
# 22     Rana hungama at #ChaySam Wedding Reception || ...
# 23                                                   NaN
# 24                                                   NaN
# 25     Moto X4 Unboxing & Overview the Moto X4 is pow...
# 26     हिंदी ख़बर के विशेष समाचार बुलेटिन '5 बड़ी ख़ब...
# 27     Here is the  #PunyalanPrivateLimited  Official...
# 28     This video about Nagarjuna Funny Comments on S...
# 29     Sunni Dawate Islami Presents\nTopic:  Annual I...
# ...                                                  ...
# 37321  Song: Aararo Music: Raghu DixitLyrics: Rafeeq ...
# 37322  Presenting the Official Video Song of Thanga S...
# 37323  Watch the teaser trailer for Tim Burton’s all-...
# 37324  Ranna kannada movies 2018 | sudeep kannada mov...
# 37325  ben banavi pade kyarek.....follow me on ...ins...
# 37326  Azhagu Tamil Serial latest Full Episode 172 Te...
# 37327  Subscribe → http://bit.ly/PyaarLafzonMeinKahan...
# 37328  Official Teaser of Ondraga Originals upcoming ...
# 37329  (Earphone Use Is Recommended)!!Funny Ramzan Sc...
# 37330  Very few stories of a Bai in our times are as ...
# 37331  अध्यात्मिक गुरु भय्यू महाराज यांच्या सुसाईड नो...
# 37332  Did you like the video? Then give me a big thu...
# 37333  Click here to Subscribe to SAB TV Channel : ht...
# 37334  Bigg Boss Telugu Season 2 EPISODE 02 | Highlig...
# 37335  Get the Happn App - http://gethap.pn/jQrR3YSub...
# 37336  Subscribers Link: http://bit.ly/2qb69dZConnect...
# 37337  To watch FULL episode of Kumkum Bhagya, CLICK ...
# 37338  This drama series revolves around loyalty, fri...
# 37339  In this interview with Rajeev Masand, YouTube ...
# 37340  Baap ka, dada ka, Jija ka, saale ka, bua ke be...
# 37341  Bhaiyyuji Maharaj | Suicide For Depression And...
# 37342  So we are back with a new comedy sketch on our...
# 37343  Believing everything you see and hear on the i...
# 37344  Priyamanaval Episode 1040Subscribe: https://go...
# 37345  Suno, Sab sort karva denge. Chacha vidhayak ha...
# 37346  PRG Music & RDC Rajasthani presents फेकू आशिक़...
# 37347  Flowers - A R Rahman Show,Book your Tickets He...
# 37348  Subscribe to Mazhavil Manorama now for your da...
# 37349  Nuabohu : Story of a rustic village girl who w...
# 37350  Check out Ee Nagaraniki Emaindi Trailer #EeNag...
#
# [37351 rows x 16 columns]

# %% [markdown]
# Imputing Missing Values
#
# - For numerical variables use mean and median
# - For categorical variables use mode

# %% [markdown]
# #### Handling Incorrect Data Types

# %%
#Check the datatypes of all the columns 
df.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %% [markdown]
# #### Outliers Analysis Using Boxplot

# %% [markdown]
# Now you need to start identifying and removing extreme values or __outliers__ from our dataset. These values can tilt our analysis and often provide us with a biased perspective of the data available. This is where you’ll start utilising visualisation to achieve your tasks. And the best visualisation to use here would be the box plot. Boxplots are one of the best ways of analysing the spread of a numeric variable
#
#
# Using a box plot you can identify the outliers as follows:

# %% [markdown]
# ![BoxPlots to Identify Outliers](images\Boxplot.png)

# %% [markdown]
# - Outliers in data can arise due to genuine reasons or because of dubious entries. In the latter case, you should go ahead and remove such entries immediately. Use a boxplot to observe, analyse and remove them.
# - In the former case, you should determine whether or not removing them would add value to your analysis procedure.

# %% [markdown]
# - You can create a box plot directly from pandas dataframe or the matplotlib way as you learnt in the previous session. Check out their official documentation here:
#    - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.boxplot.html
#    - https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.boxplot.html

# %% [markdown]
# ### Histograms
#
# Histograms can also be used in conjuction with boxplots for data cleaning and data handling purposes. You can use it to check the spread of a numeric variable. Histograms generally work by bucketing the entire range of values that a particular variable takes to specific __bins__. After that, it uses vertical bars to denote the total number of records in a specific bin, which is also known as its __frequency__.

# %% [markdown]
# ![Histogram](images\Histogram.png)

# %% [markdown]
# You can adjust the number of bins to improve its granularity

# %% [markdown]
# ![Bins change](images\Granular.png)

# %% [markdown]
# You'll be using plt.hist() to plot a histogram. Check out its official documentation:https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.hist.html

# %% [markdown]
# ### Session 2 - Data Visualisation with Seaborn

# %% [markdown]
# Seaborn is Python library to create statistical graphs easily. It is built on top of matplotlib and closely integrated with pandas.
#
# _Functionalities of Seaborn_ :
#
# - Dataset oriented API
# - Analysing univariate and bivariate distributions
# - Automatic estimation and plotting of  linear regression models
# - Convenient views for complex datasets
# - Concise control over style
# - Colour palettes

# %% [markdown]
# #### Distribution Plots

# %% [markdown]
# A distribution plot is pretty similar to the histogram functionality in matplotlib. Instead of a frequency plot, it plots an approximate probability density for that rating bucket. And the curve (or the __KDE__) that gets drawn over the distribution is the approximate probability density curve.
#
# The following is an example of a distribution plot. Notice that now instead of frequency on the left axis, it has the density for each bin or bucket.

# %% [markdown]
# ![Distplot](images\Distplot.png)

# %% [markdown]
# You'll be using sns.distplot for plotting a distribution plot. Check out its official documentation: https://seaborn.pydata.org/generated/seaborn.distplot.html

# %% [markdown]
# #### Styling Options
#
# One of the biggest advantages of using Seaborn is that you can retain its aesthetic properties and also the Matplotlib functionalities to perform additional customisations. Before we continue with our case study analysis, let’s study some styling options that are available in Seaborn.

# %% [markdown]
# -  Check out the official documentation:https://seaborn.pydata.org/generated/seaborn.set_style.html

# %% [markdown]
# #### Pie-Chart and Bar Chart

# %% [markdown]
# For analysing how a numeric variable changes across several categories of a categorical variable you utilise either a pie chart or a box plot

# %% [markdown]
# For example, if you want to visualise the responses of a marketing campaign, you can use the following views:

# %% [markdown]
# ![PieChart](images\pie.png)

# %% [markdown]
# ![barChart](images\bar.png)

# %% [markdown]
# - You'll be using the pandas method of plotting both a pie chart and a bar chart. Check out their official documentations:
#    - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.bar.html
#    - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.pie.html

# %% [markdown]
# #### Scatter Plots

# %% [markdown]
# Scatterplots are perhaps one of the most commonly used as well one of the most powerful visualisations you can use in the field of machine learning. They are pretty crucial in revealing relationships between the data points and you can generally deduce some sort of trends in the data with the help of a scatter plot.

# %% [markdown]
# ![Scatterplot](images\scatter.png)

# %% [markdown]
# - They're pretty useful in regression problems to check whether a linear trend exists in the data or not. For example, in the image below, creating a linear model in the first case makes far more sense since a clear straight line trend is visible.

# %% [markdown]
# ![Scatterplot-Reg](images\regression3.png)

# %% [markdown]
# - Also, they help in observing __naturally occuring clusters__. In the following image, the marks of students in Maths and Biology has been plotted.You can clearly group the students to 4 clusters now. Cluster 1 are students who score very well in Biology but very poorly in Maths, Cluster 2 are students who score equally well in both the subjects and so on.

# %% [markdown]
# ![Scatter-Clusters](images\Clusters.png)

# %% [markdown]
# **Note**: You'll be studying about both Regression and Clustering in greater detail in the machine learning modules

# %% [markdown]
# You'll be using **sns.jointplot()** for creating a scatter plot. Check out its documentation:
# https://seaborn.pydata.org/generated/seaborn.jointplot.html

# %% [markdown]
# **Reg Plots**
#
# - These are an extension to the jointplots, where a regression line is added to the view

# %% [markdown]
# **Pair Plots**

# %% [markdown]
#  - When you have several numeric variables, making multiple scatter plots becomes rather tedious. Therefore, a pair plot visualisation is preferred where all the scatter plots are in a single view in the form of a matrix
#  - For the non-diagonal views, it plots a **scatter plot** between 2 numeric variables
#  - For the diagonal views, it plots a **histogram**

# %% [markdown]
# Pair Plots help in identifying the trends between a target variable and the predictor variables pretty quickly. For example, say you want to predict how your company’s profits are affected by three different factors. In order to choose which you created a pair plot containing profits and the three different factors as the variables. Here are the scatterplots of profits vs the three variables that you obtained from the pair plot.

# %% [markdown]
# ![Pairplots](images\pairplots2.png)

# %% [markdown]
# It is clearly visible that the left-most factor is the most prominently related to the profits, given how linearly scattered the points are and how randomly scattered the rest two factors are.

# %% [markdown]
# You'll be using **sns.pairplot()** for this visualisation. Check out its official documentation:https://seaborn.pydata.org/generated/seaborn.pairplot.html

# %% [markdown]
# **Bar Charts Revisited**

# %% [markdown]
# - Here, you'll be using bar charts once again, this time using the **sns.barplot()** function. Check out its official documentation:https://seaborn.pydata.org/generated/seaborn.barplot.html
# - You can modify the **estimator** parameter to change the aggregation value of your barplot

# %% [markdown]
# __Box Plots Revisited__
#
# - Apart from outlier analysis, box plots are great at comparing the spread and analysing a numerical variable across several categories
# - Here you'll be using **sns.boxplot()** function to plot the visualisation. Check out its documentation: https://seaborn.pydata.org/generated/seaborn.boxplot.html

# %% [markdown]
# #### Heat Maps

# %% [markdown]
# Heat mapsutilise the concept of using colours and colour intensities to visualise a range of values. You must have seen heat maps in cricket or football broadcasts on television to denote the players’ areas of strength and weakness.

# %% [markdown]
# ![HeatMap](images\heatmap1.png)

# %% [markdown]
# - In python, you can create a heat map whenever you have a rectangular grid or table of numbers analysing any two features

# %% [markdown]
# ![heatmap2](images\heatmap2.png)

# %% [markdown]
# - You'll be using **sns.heatmap()** to plot the visualisation. Checkout its official documentation :https://seaborn.pydata.org/generated/seaborn.heatmap.html

# %% [markdown]
# ### Session 3: Additional Visualisations

# %% [markdown]
# #### Line Plots

# %% [markdown]
# - A line plot tries to observe trends using time dependent data.
# -  For this part, you'll be using **pd.to_datetime()** function. Check out its documentation:https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_datetime.html

# %% [markdown]
# #### Stacked Bar Charts

# %% [markdown]
# - A stacked bar chart breaks down each bar of the bar chart on the basis of a different category
# - For example, for the Campaign Response bar chart you saw earlier, the stacked bar chart is also showing the Gender bifurcation as well

# %% [markdown]
# ![Stacked](images\stacked.png)

# %% [markdown]
# #### Plotly

# %% [markdown]
# Plotly is a Python library used for creating interactive visual charts. You can take a look at how you can use it to create aesthetic looking plots with a lot of user-friendly functionalities like hover, zoom, etc.

# %% [markdown]
# Check out this link for installation and documentation:https://plot.ly/python/getting-started/
